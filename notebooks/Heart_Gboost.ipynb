# %%
import pandas as pd
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
X = data.iloc[:,:-1]
y = data.target

# %%
from sklearn.feature_selection import SelectKBest , f_regression
selector = SelectKBest(score_func=f_regression , k=5)
x_new = selector.fit_transform(X , y)

# %%
selector.scores_
# Out:
# array([16.11669982, 25.79219115, 69.77227149,  6.45816867,  2.20298345,
#         0.23694234,  5.77720891, 65.1201044 , 70.95243822, 68.55143941,
#        40.90207063, 54.5598338 , 40.40769615])

# %%
x_new
# Out:
# array([[  3. , 150. ,   0. ,   2.3,   0. ],
#        [  2. , 187. ,   0. ,   3.5,   0. ],
#        [  1. , 172. ,   0. ,   1.4,   0. ],
#        ...,
#        [  0. , 141. ,   0. ,   3.4,   2. ],
#        [  0. , 115. ,   1. ,   1.2,   1. ],
#        [  1. , 174. ,   0. ,   0. ,   1. ]])

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data_new = data[['cp','thalach','exang','oldpeak','ca','target']]
data_new.head()
# Out:
#    cp  thalach  exang  oldpeak  ca  target
# 0   3      150      0      2.3   0       1
# 1   2      187      0      3.5   0       1
# 2   1      172      0      1.4   0       1
# 3   1      178      0      0.8   0       1
# 4   0      163      1      0.6   0       1

# %%
X_new = data_new.iloc[:,:-1]
y_new = data_new.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x_new , y_new , random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1 , n_estimators=20)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=20)

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8289473684210527

# %% [markdown]
#  با استاندارد اسکیل کردن

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit_transform(x_new,y_new)
# Out:
# array([[ 1.97312292,  0.01544279, -0.69663055,  1.08733806, -0.71442887],
#        [ 1.00257707,  1.63347147, -0.69663055,  2.12257273, -0.71442887],
#        [ 0.03203122,  0.97751389, -0.69663055,  0.31091206, -0.71442887],
#        ...,
#        [-0.93851463, -0.37813176, -0.69663055,  2.03630317,  1.24459328],
#        [-0.93851463, -1.51512489,  1.43548113,  0.13837295,  0.26508221],
#        [ 0.03203122,  1.0649749 , -0.69663055, -0.89686172,  0.26508221]])

# %%
x_train , x_test , y_train , y_test = train_test_split(x_new , y_new , random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1 , n_estimators=20)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=20)

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8289473684210527

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1 , n_estimators=20)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=20)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        35
#            1       0.83      0.85      0.84        41
#
#     accuracy                           0.83        76
#    macro avg       0.83      0.83      0.83        76
# weighted avg       0.83      0.83      0.83        76

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1 , n_estimators=5)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=5)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82        35
#            1       0.84      0.88      0.86        41
#
#     accuracy                           0.84        76
#    macro avg       0.84      0.84      0.84        76
# weighted avg       0.84      0.84      0.84        76

# %%
param ={'n_estimators' : [50,100,200] ,'learning_rate' : [0.01 , 0.1 , 0.2] ,'loss' : ['log_loss', 'exponential'] , 'max_depth' : [3,5,7] , 'min_samples_split' : [2,5,10] , 'min_samples_leaf' : [1,2,4] }

# %%
from sklearn.model_selection import GridSearchCV
gboost = GradientBoostingClassifier()
grid_search = GridSearchCV(estimator=gboost,scoring='accuracy',param_grid=param , n_jobs=-1 , cv = 2 , verbose=10)
grid_search.fit(x_train , y_train)
# Out:
# Fitting 2 folds for each of 486 candidates, totalling 972 fits
# GridSearchCV(cv=2, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'loss': ['log_loss', 'exponential'],
#                          'max_depth': [3, 5, 7], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy', verbose=10)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1,
#  'loss': 'exponential',
#  'max_depth': 3,
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 50}

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1 ,loss='exponential' ,  n_estimators=50 , max_depth=3 , min_samples_split=5 , min_samples_leaf=2)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(loss='exponential', min_samples_leaf=2,
#                            min_samples_split=5, n_estimators=50)

# %%
y_pred = model.predict(x_test)

# %%
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        35
#            1       0.83      0.85      0.84        41
#
#     accuracy                           0.83        76
#    macro avg       0.83      0.83      0.83        76
# weighted avg       0.83      0.83      0.83        76

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
data1 = data[['cp','thalach','slope','target']]
data1.head()
# Out:
#    cp  thalach  slope  target
# 0   3      150      0       1
# 1   2      187      0       1
# 2   1      172      2       1
# 3   1      178      2       1
# 4   0      163      2       1

# %%
X =data1.iloc[:,:-1]
y = data1.target

# %%
ss = StandardScaler()
X = ss.fit_transform(X)

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , random_state=41)

# %%
param ={'n_estimators' : [50,100,200] ,'learning_rate' : [0.01 , 0.1 , 0.2] ,'loss' : ['log_loss', 'exponential'] , 'max_depth' : [3,5,7] , 'min_samples_split' : [2,5,10] , 'min_samples_leaf' : [1,2,4] }
from sklearn.model_selection import GridSearchCV
gboost = GradientBoostingClassifier()
grid_search = GridSearchCV(estimator=gboost,scoring='accuracy',param_grid=param , n_jobs=-1 , cv = 5)
grid_search.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'loss': ['log_loss', 'exponential'],
#                          'max_depth': [3, 5, 7], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.01,
#  'loss': 'log_loss',
#  'max_depth': 3,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(learning_rate=0.1  ,  n_estimators=8)
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=8)

# %%
y_pred = model.predict(x_test)

# %%
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68        38
#            1       0.69      0.63      0.66        38
#
#     accuracy                           0.67        76
#    macro avg       0.67      0.67      0.67        76
# weighted avg       0.67      0.67      0.67        76

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X = ss.fit_transform(X)

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , random_state=50)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(n_estimators=13)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77        33
#            1       0.80      0.91      0.85        43
#
#     accuracy                           0.82        76
#    macro avg       0.82      0.80      0.81        76
# weighted avg       0.82      0.82      0.81        76

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        33
#            1       0.80      0.93      0.86        43
#
#     accuracy                           0.83        76
#    macro avg       0.84      0.81      0.82        76
# weighted avg       0.84      0.83      0.83        76

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=200)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75        33
#            1       0.79      0.88      0.84        43
#
#     accuracy                           0.80        76
#    macro avg       0.81      0.79      0.79        76
# weighted avg       0.80      0.80      0.80        76

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.64      0.72        33
#            1       0.76      0.91      0.83        43
#
#     accuracy                           0.79        76
#    macro avg       0.80      0.77      0.78        76
# weighted avg       0.80      0.79      0.78        76

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76        33
#            1       0.78      0.93      0.85        43
#
#     accuracy                           0.82        76
#    macro avg       0.83      0.80      0.80        76
# weighted avg       0.83      0.82      0.81        76

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 model = DecisionTreeClassifier()
# ----> 3 model.fit(x_train,y_train)
#       4 y_pred = model.predict(x_test)
#       5 print(metrics.classification_report(y_test , y_pred))
#
# NameError: name 'x_train' is not defined

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.drop(columns=['fbs'] , inplace=True)

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X , y , random_state=41 , test_size=25)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train , y_train)
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.93      0.93      0.93        14
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(n_estimators=50)
model.fit(x_train , y_train)
y_pred = model.predict(x_test)

# %%
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.93      0.93      0.93        14
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.93      0.93      0.93        14
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        11
#            1       0.93      1.00      0.97        14
#
#     accuracy                           0.96        25
#    macro avg       0.97      0.95      0.96        25
# weighted avg       0.96      0.96      0.96        25

# %%
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[10  1]
#  [ 0 14]]
